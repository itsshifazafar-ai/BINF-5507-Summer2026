# %% [markdown]
# # Lab 1 - Practice wih GitHub and Calling Functions from Other Scripts

# %%
from Scripts.functions import myCoolFunction

# %%
myCoolFunction(True)
myCoolFunction(False)
# Out:
# This is a cool function!
# This function could use some work.

# %% [markdown]
# We have downloaded a dataset from The Cancer Imaging Archive (TCIA ) in sarcoma. The dataset contains clinical features and outcomes for 51 sarcoma patients.

# %%
import pandas as pd

raw_data = pd.read_excel("INFOClinical_STS.xlsx", engine="openpyxl")
raw_data.head()
# Out:
#   Patient ID   Age     Sex               Histological type      MSKCC type  \
# 0    STS_001  59.0    Male        pleiomorphic liposarcoma     Liposarcoma
# 1    STS_002  61.0    Male     pleiomorphic leiomyosarcoma  Leiomyosarcoma
# 2    STS_003  17.0  Female             epithelioid sarcoma           Other
# 3    STS_004  22.0  Female  malignant fibrous histiocytoma             MFH
# 4    STS_005  83.0  Female     pleiomorphic leiomyosarcoma  Leiomyosarcoma
#
#   Site of primary STS         Grade  Time – diagnosis to MRI scan (days)  \
# 0          left thigh          High                                 -7.0
# 1        left buttock          High                                -10.0
# 2       right buttock  Intermediate                                -13.0
# 3         right thigh           Low                                 -6.0
# 4         left biceps          High                                -24.0
#
# ...

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
